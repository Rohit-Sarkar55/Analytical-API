# %%
import requests

# %%
path="/api/events/"
baseurl="http://localhost:8002"
create_endpoint=f"{baseurl}{path}"
response = requests.post(create_endpoint, json={"page":"/tests"})
print(response.headers)
print(response.ok)
if response.ok:
    data= response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Sun, 08 Jun 2025 18:42:12 GMT', 'server': 'uvicorn', 'content-length': '127', 'content-type': 'application/json'}
# True
# {'page': '/tests', 'created_at': '2025-06-08T18:42:13.184634Z', 'description': '', 'id': 7, 'updated_at': '2025-06-08T18:42:13.184637Z'} <class 'dict'> None

# %%
detail_path="/api/events/3"
detail_endpoint=f"{baseurl}{detail_path}"
headers={
    "Content-Type":"application/json"
}
response = requests.put(detail_endpoint,json={"description":"testing update"},headers=headers) #putting headers is optional here unless you want to specify
print(response.headers)
print(response.ok)
if response.ok:
    data= response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Sun, 08 Jun 2025 18:43:03 GMT', 'server': 'uvicorn', 'content-length': '141', 'content-type': 'application/json'}
# True
# {'page': '/tests', 'created_at': '2025-06-08T18:42:05.900805Z', 'description': 'testing update', 'id': 3, 'updated_at': '2025-06-08T18:43:04.207926Z'} <class 'dict'> None
