# %%
import requests

# %%
path="/api/events/"
baseurl="http://localhost:8002"
create_endpoint=f"{baseurl}{path}"
response = requests.post(create_endpoint, json={"page":"/tests"})
print(response.headers)
print(response.ok)
if response.ok:
    data= response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Sun, 08 Jun 2025 17:17:49 GMT', 'server': 'uvicorn', 'content-length': '42', 'content-type': 'application/json'}
# True
# {'id': 14, 'page': '/tests', 'description': ''} <class 'dict'> None

# %%
detail_path="/api/events/12"
detail_endpoint=f"{baseurl}{detail_path}"
headers={
    "Content-Type":"application/json"
}
response = requests.put(detail_endpoint,json={"description":"hello virat"},headers=headers) #putting headers is optional here unless you want to specify
print(response.headers)
print(response.ok)
if response.ok:
    data= response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Sun, 08 Jun 2025 17:19:08 GMT', 'server': 'uvicorn', 'content-length': '53', 'content-type': 'application/json'}
# True
# {'id': 12, 'page': '/tests', 'description': 'hello virat'} <class 'dict'> None
